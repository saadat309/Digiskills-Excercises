# %% [markdown]
# <a href="https://colab.research.google.com/github/saadat309/Digiskills-Excercises/blob/main/Ai_with_python_Exercise_1_task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
marks = np.array([78, 85, 92, 67, 88])
print(marks)
# Out:
# [78 85 92 67 88]

# %%
marks_float = marks.astype(float)
print(marks_float)
# Out:
# [78. 85. 92. 67. 88.]
